# %%
pip
# Out:
# Usage:
#   C:\ProgramData\Anaconda3\python.exe -m pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   help                        Show help for commands.
#
# General Options:
# ...

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install rasa
# Out:
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\30\6b\50\6c75775b681fb36cdfac7f19799888ef9d8813aff9e379663e
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\27\31\04\c6e7a0092d67d9e6173ee8839b0d7a30825bf9d7aaa47c14e2
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\c5\47\19\47188b3036316651250c4f7df23d59a3b524c82921bfb6daa3
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\d1\86\9d\16127127306a92d7fd30267890a5634026c045391979c4c317
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\43\16\17\cf25bc9362c6319411371068d07cee5611032ba0210423987c
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\3b\d4\92\3458f0e1a3e1a9c8935d3b2db89a75d74d8d45601fedec752f
# ...
#   Stored in directory: C:\Users\lenovo\AppData\Local\pip\Cache\wheels\ae\5f\fb\705cb87c56fb25aed2fa6795a1c751ca83b79fc76f69e37d0c
# ...

# %%
import tensorflow

# %%
import keras
# Out:
# Using TensorFlow backend.

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/5a/af/dabae171f885ec4d9b2fe6aaf74c1d50a8d32106d840b9fb8eb0095a578d/opencv_python-4.2.0.32-cp37-cp37m-win_amd64.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import PIL

# %%
from PIL import image
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-7892611e7a30> in <module>
# ----> 1 from PIL import image
#
# ImportError: cannot import name 'image' from 'PIL' (C:\ProgramData\Anaconda3\lib\site-packages\PIL\__init__.py)
