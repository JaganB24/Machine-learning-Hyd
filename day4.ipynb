# %% [markdown]
# ## topics
#  - linalg
#  - vectorize
#  - how to read an image in numpy array

# %%
import numpy as np

# %%
dir(np.linalg)
# Out:
# ['LinAlgError',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_umath_linalg',
#  'absolute_import',
#  'cholesky',
#  'cond',
#  'det',
#  'division',
#  'eig',
#  'eigh',
#  'eigvals',
#  'eigvalsh',
#  'info',
#  'inv',
#  'lapack_lite',
#  'linalg',
#  'lstsq',
#  'matrix_power',
#  'matrix_rank',
#  'multi_dot',
#  'norm',
#  'pinv',
#  'print_function',
#  'qr',
#  'slogdet',
#  'solve',
#  'svd',
#  'tensorinv',
#  'tensorsolve',
#  'test']

# %%
dir(np.linalg.linalg)
# Out:
# ['Inf',
#  'LinAlgError',
#  '_A',
#  '_L',
#  '_N',
#  '_S',
#  '_V',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_assertFinite',
#  '_assertNdSquareness',
#  '_assertNoEmpty2d',
#  '_assertRank2',
#  '_assertRankAtLeast2',
#  '_commonType',
#  '_complexType',
#  '_complex_types_map',
#  '_cond_dispatcher',
#  '_convertarray',
#  '_eigvalsh_dispatcher',
#  '_fastCT',
#  '_fastCopyAndTranspose',
#  '_isEmpty2d',
#  '_linalgRealType',
#  '_linalg_error_extobj',
#  '_lstsq_dispatcher',
#  '_makearray',
#  '_matrix_power_dispatcher',
#  '_matrix_rank_dispatcher',
#  '_multi_dot',
#  '_multi_dot_matrix_chain_order',
#  '_multi_dot_three',
#  '_multi_svd_norm',
#  '_multidot_dispatcher',
#  '_norm_dispatcher',
#  '_pinv_dispatcher',
#  '_qr_dispatcher',
#  '_raise_linalgerror_eigenvalues_nonconvergence',
#  '_raise_linalgerror_lstsq',
#  '_raise_linalgerror_nonposdef',
#  '_raise_linalgerror_singular',
#  '_raise_linalgerror_svd_nonconvergence',
#  '_realType',
#  '_real_types_map',
#  '_solve_dispatcher',
#  '_svd_dispatcher',
#  '_tensorinv_dispatcher',
#  '_tensorsolve_dispatcher',
#  '_to_native_byte_order',
#  '_umath_linalg',
#  '_unary_dispatcher',
#  'abs',
#  'absolute_import',
#  'add',
#  'all',
#  'amax',
#  'amin',
#  'array',
#  'array_function_dispatch',
#  'asanyarray',
#  'asarray',
#  'atleast_2d',
#  'cdouble',
#  'cholesky',
#  'complexfloating',
#  'cond',
#  'count_nonzero',
#  'csingle',
#  'det',
#  'divide',
#  'division',
#  'dot',
#  'double',
#  'eig',
#  'eigh',
#  'eigvals',
#  'eigvalsh',
#  'empty',
#  'empty_like',
#  'errstate',
#  'eye',
#  'fastCopyAndTranspose',
#  'finfo',
#  'fortran_int',
#  'functools',
#  'get_linalg_error_extobj',
#  'geterrobj',
#  'inexact',
#  'intc',
#  'intp',
#  'inv',
#  'isComplexType',
#  'isfinite',
#  'isnan',
#  'lapack_lite',
#  'lstsq',
#  'matmul',
#  'matrix_power',
#  'matrix_rank',
#  'moveaxis',
#  'multi_dot',
#  'multiply',
#  'newaxis',
#  'norm',
#  'normalize_axis_index',
#  'object_',
#  'operator',
#  'overrides',
#  'pinv',
#  'print_function',
#  'product',
#  'qr',
#  'set_module',
#  'single',
#  'slogdet',
#  'solve',
#  'sqrt',
#  'sum',
#  'svd',
#  'swapaxes',
#  'tensorinv',
#  'tensorsolve',
#  'transpose',
#  'triu',
#  'warnings',
#  'zeros']

# %%
print(np.dot(2,3))
print(np.dot([1],[2]))
# Out:
# 6
# 2

# %%
a = np.full((2,2),4)

b = np.eye(2)
print(a)
print(b)
# Out:
# [[4 4]
#  [4 4]]
# [[1. 0.]
#  [0. 1.]]

# %%
print(a*b)
# Out:
# [[4. 0.]
#  [0. 4.]]

# %%
print(np.dot(a,b))
# Out:
# [[4. 4.]
#  [4. 4.]]

# %%
np.matmul(a,b)
# Out:
# array([[4., 4.],
#        [4., 4.]])

# %%
c = np.diag([1,2,3])
print(np.linalg.eig(c))
# Out:
# (array([1., 2., 3.]), array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]]))

# %%
d = np.random.randint(100,size=(3,3))
values,vector=np.linalg.eig(d)

# %%
values
# Out:
# array([182.2006579  +0.j        , -19.10032895+31.50178463j,
#        -19.10032895-31.50178463j])

# %%
vector
# Out:
# array([[ 0.49957183+0.j        , -0.75336566+0.j        ,
#         -0.75336566-0.j        ],
#        [ 0.66136612+0.j        ,  0.04369521+0.3803689j ,
#          0.04369521-0.3803689j ],
#        [ 0.55948445+0.j        ,  0.37814505-0.37796392j,
#          0.37814505+0.37796392j]])

# %%
np.linalg.det(np.eye(2))
# Out:
# 1.0

# %%
d = np.array([[1,2],[0,1]])
np.linalg.det(d)
# Out:
# 1.0

# %%
np.random.seed(45)
a = np.random.randint(20,50,10)
b = np.random.randint(20,50,10)
c = a>b
print(a)
print(b)
print(c[a>b])
# Out:
# [31 23 48 20 49 41 23 24 45 44]
# [35 21 34 41 45 42 28 43 34 28]
# [ True  True  True  True  True]

# %%
np.maximum(a,b)
# Out:
# array([35, 23, 48, 41, 49, 42, 28, 43, 45, 44])

# %%
def large(n1,n2):
    if n1>n2:
        return n1
    else:
        return n2
large(56,54)
# Out:
# 56

# %%
vlarge = np.vectorize(large)

vlarge(a,b)
# Out:
# array([35, 23, 48, 41, 49, 42, 28, 43, 45, 44])

# %%
import matplotlib.pyplot as plt
img=plt.imread('n1.jpg')
print(img)
plt.imshow(img)
# Out:
# [[[246 242 231]
#   [246 242 231]
#   [246 242 231]
#   ...
#   [218 213 173]
#   [207 198 155]
#   [193 184 141]]
#
#  [[246 242 231]
#   [246 242 231]
#   [246 242 231]
#   ...
#   [226 221 181]
#   [220 212 166]
#   [210 202 156]]
#
#  [[246 242 231]
#   [246 242 231]
#   [246 242 231]
#   ...
#   [220 215 175]
#   [225 217 170]
#   [223 215 168]]
#
#  ...
#
#  [[231 229 208]
#   [231 229 208]
#   [231 229 208]
#   ...
#   [236 230 206]
#   [236 230 206]
#   [236 230 206]]
#
#  [[231 229 208]
#   [231 229 208]
#   [231 229 208]
#   ...
#   [236 230 206]
#   [236 230 206]
#   [236 230 206]]
#
#  [[231 229 208]
#   [231 229 208]
#   [231 229 208]
#   ...
#   [237 229 206]
#   [236 230 206]
#   [236 230 206]]]

# %%
plt.imshow(img[:512,:400])

# %%
img.shape
# Out:
# (1024, 818, 3)

# %%
np.max(img)
# Out:
# 255

# %%
np.min(img)
# Out:
# 0

# %%
plt.imshow(img[:256,:256,:])

# %%
plt.imshow(img[:250,:50,:200])

# %%
img1=np.resize(img,(1000,818,3))
plt.imshow(img1)
