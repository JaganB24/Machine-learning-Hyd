# %% [markdown]
# # pandas

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.2'

# %% [markdown]
# - series-1d
# - dataframe-2d
# - pannel-3d

# %%
pd.Series([12,15,46])
# Out:
# 0    12
# 1    15
# 2    46
# dtype: int64

# %%
import numpy as np
c=np.array([56,12,41])

# %%
pd.Series([12,13,14],index=['jagan','kaushik','rishi'])
# Out:
# jagan      12
# kaushik    13
# rishi      14
# dtype: int64

# %%
pd.Series([12,13,14],index=[1,2,3])
# Out:
# 1    12
# 2    13
# 3    14
# dtype: int64

# %%
j=pd.Series([12,13,14],index=[1,2,3])
print(j[1],j[1])
# Out:
# 12 12

# %%
m= pd.Series([12,13,14],index=['jagan','kaushik','rishi'])
print(m[0],m['rishi'])
# Out:
# 12 14

# %%
pd.Series((1,2,3))
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series(c)
# Out:
# 0    56
# 1    12
# 2    41
# dtype: int32

# %%
d={'kau':12,'jag':22,'ris':10}
e=pd.Series(d)
print(e)
# Out:
# kau    12
# jag    22
# ris    10
# dtype: int64

# %%
type(e)
# Out:
# pandas.core.series.Series

# %%
e.index
# Out:
# Index(['kau', 'jag', 'ris'], dtype='object')

# %%
d2 = {'idn':[15,16,17],
     'sname':['jagan','vineeth','bhavani'],
     'course':['msc','msc','msc']}
pd.DataFrame(d2)
# Out:
#    idn    sname course
# 0   15    jagan    msc
# 1   16  vineeth    msc
# 2   17  bhavani    msc

# %%
print(pd.DataFrame(d2))
# Out:
#    idn    sname course
# 0   15    jagan    msc
# 1   16  vineeth    msc
# 2   17  bhavani    msc

# %%
pd.DataFrame(d2,index=None)
# Out:
#    idn    sname course
# 0   15    jagan    msc
# 1   16  vineeth    msc
# 2   17  bhavani    msc

# %%
data = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.csv')
data
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
data.head()
# Out:
#              Timestamp              Name                            MailId  \
# 0  30/01/2020 15:00:07     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1  30/01/2020 15:00:20          R deepak            deepakrella9@gmail.com
# 2  30/01/2020 15:00:23     P K CHAITANYA              chaitu1495@gmail.com
# 3  30/01/2020 15:00:25        B SRIKANTH           srikanthbisai@gmail.com
# 4  30/01/2020 15:00:28  Himaja cherukuri         himajacherukuri@gmail.com
#
#   Branch Qualification    RollNumber
# 0     IT        B.Tech    161FA07039
# 1    MCA            PG  121722501019
# 2    MCA            PG  121722501015
# 3    MCA            PG  121722501002
# 4    cse         BTech    161fa04079

# %%
data.shape
# Out:
# (26, 6)

# %%
data.tail()
# Out:
#               Timestamp                       Name  \
# 21  30/01/2020 15:02:41           G. Vineeth Kumar
# 22  30/01/2020 15:02:49  JAYA NAVEEN KUMAR DUPPATI
# 23  30/01/2020 15:02:59                   vikram S
# 24  30/01/2020 15:04:10            SAI TEJA JALADI
# 25  30/01/2020 15:07:38         SAIKUMAR MANIKONDA
#
#                            MailId                  Branch Qualification  \
# 21          121822502016@gitam.in            Data Science          M.Sc
# 22    duppatijayanaveen@gmail.com                     I.T        B.TECH
# 23  vikramsabbavarapu60@gmail.com       civil engineering        B-tech
# 24    saitejajaladi2000@gmail.com                     I.T        B.TECH
# 25          saikumarm64@gmail.com  Automobile Engineering           B.E
#
#       RollNumber
# 21  121822502016
# 22    161FA07012
# 23    133J1A0150
# 24    161FA07025
# 25  245112769310

# %%
data['Name']
# Out:
# 0                 Sai Naga Raju
# 1                      R deepak
# 2                 P K CHAITANYA
# 3                    B SRIKANTH
# 4              Himaja cherukuri
# 5                 M.Geethanjali
# 6                     M.Nikhita
# 7              DASARI PAVAN SAI
# 8                 B Jagan Mohan
# 9             k.parameswara rao
# 10             B.Ravindra kumar
# 11          P.M.S.Bhargav Kumar
# 12        Thatavarti kavya sree
# 13                 Harish Bandi
# 14       M.Bhavani Sankar Reddy
# 15               Devendra Kumar
# 16                      M.Ramya
# 17              T.V.Naga Jyothi
# 18               Ananda Lakshmi
# 19                  K . krishna
# 20         Md.Ali Asghar Khoyee
# 21             G. Vineeth Kumar
# 22    JAYA NAVEEN KUMAR DUPPATI
# 23                     vikram S
# 24              SAI TEJA JALADI
# 25           SAIKUMAR MANIKONDA
# Name: Name, dtype: object

# %%
data[['Name','MailId']]
# Out:
#                          Name                            MailId
# 0               Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 1                    R deepak            deepakrella9@gmail.com
# 2               P K CHAITANYA              chaitu1495@gmail.com
# 3                  B SRIKANTH           srikanthbisai@gmail.com
# 4            Himaja cherukuri         himajacherukuri@gmail.com
# 5               M.Geethanjali           geethamuppuri@gmail.com
# 6                   M.Nikhita            muvvanikhita@gmail.com
# 7            DASARI PAVAN SAI          pavandasari226@gmail.com
# 8               B Jagan Mohan           bjaganmohan24@gmail.com
# 9           k.parameswara rao    parameshkarumuri1997@gmail.com
# 10           B.Ravindra kumar    ravindrakumarroyal12@gmail.com
# 11        P.M.S.Bhargav Kumar     bhargavperumalla123@gmail.com
# 12      Thatavarti kavya sree         kavyathatavarti@gmail.com
# 13               Harish Bandi           harishbandi12@gmail.com
# ...

# %%
data.sample()
# Out:
#               Timestamp      Name                         MailId  \
# 23  30/01/2020 15:02:59  vikram S  vikramsabbavarapu60@gmail.com
#
#                Branch Qualification  RollNumber
# 23  civil engineering        B-tech  133J1A0150

# %%
data.shape[0]
# Out:
# 26

# %%
data.index
# Out:
# RangeIndex(start=0, stop=26, step=1)

# %%
data.columns
# Out:
# Index(['Timestamp', 'Name', 'MailId', 'Branch', 'Qualification', 'RollNumber'], dtype='object')

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
data.isnull()
# Out:
#     Timestamp   Name  MailId  Branch  Qualification  RollNumber
# 0       False  False   False   False          False       False
# 1       False  False   False   False          False       False
# 2       False  False   False   False          False       False
# 3       False  False   False   False          False       False
# 4       False  False   False   False          False       False
# 5       False  False   False   False          False       False
# 6       False  False   False   False          False       False
# 7       False  False   False   False          False       False
# 8       False  False   False   False          False       False
# 9       False  False   False   False          False       False
# 10      False  False   False   False          False       False
# 11      False  False   False   False          False       False
# 12      False  False   False   False          False       False
# 13      False  False   False   False          False       False
# ...

# %%
data.isnull().sum()
# Out:
# Timestamp        0
# Name             0
# MailId           0
# Branch           0
# Qualification    0
# RollNumber       0
# dtype: int64

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
data1 = pd.read_csv('https://raw.githubusercontent.com/sumathi16/Machine-Learning-with-Python/master/data/Student%20Data%20ML%20Jan%20(Responses)%20-%20Form%20responses%201.tsv','\t')
data1
# Out:
#               Timestamp                       Name  \
# 0   30/01/2020 15:00:07              Sai Naga Raju
# 1   30/01/2020 15:00:20                   R deepak
# 2   30/01/2020 15:00:23              P K CHAITANYA
# 3   30/01/2020 15:00:25                 B SRIKANTH
# 4   30/01/2020 15:00:28           Himaja cherukuri
# 5   30/01/2020 15:00:28              M.Geethanjali
# 6   30/01/2020 15:00:33                  M.Nikhita
# 7   30/01/2020 15:00:37           DASARI PAVAN SAI
# 8   30/01/2020 15:00:39              B Jagan Mohan
# 9   30/01/2020 15:00:41          k.parameswara rao
# 10  30/01/2020 15:00:43           B.Ravindra kumar
# 11  30/01/2020 15:00:44        P.M.S.Bhargav Kumar
# 12  30/01/2020 15:00:45      Thatavarti kavya sree
# 13  30/01/2020 15:01:10               Harish Bandi
# 14  30/01/2020 15:01:16     M.Bhavani Sankar Reddy
# 15  30/01/2020 15:01:24             Devendra Kumar
# 16  30/01/2020 15:01:35                    M.Ramya
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers:
#
# read_csv(filepath_or_buffer, sep=',', delimiter=None, header='infer', names=None, index_col=None, usecols=None, squeeze=False, prefix=None, mangle_dupe_cols=True, dtype=None, engine=None, converters=None, true_values=None, false_values=None, skipinitialspace=False, skiprows=None, skipfooter=0, nrows=None, na_values=None, keep_default_na=True, na_filter=True, verbose=False, skip_blank_lines=True, parse_dates=False, infer_datetime_format=False, keep_date_col=False, date_parser=None, dayfirst=False, iterator=False, chunksize=None, compression='infer', thousands=None, decimal=b'.', lineterminator=None, quotechar='"', quoting=0, doublequote=True, escapechar=None, comment=None, encoding=None, dialect=None, tupleize_cols=None, error_bad_lines=True, warn_bad_lines=True, delim_whitespace=False, low_memory=True, memory_map=False, float_precision=None)
#     Read a comma-separated values (csv) file into DataFrame.
#
# ...

# %%
data3=pd.read_excel('student.xlsx')
data3
# Out:
#                  Timestamp                       Name  \
# 0  2020-01-30 15:00:06.734              Sai Naga Raju
# 1  2020-01-30 15:00:19.555                   R deepak
# 2  2020-01-30 15:00:23.470              P K CHAITANYA
# 3  2020-01-30 15:00:25.434                 B SRIKANTH
# 4  2020-01-30 15:00:27.759           Himaja cherukuri
# 5  2020-01-30 15:00:28.333              M.Geethanjali
# 6  2020-01-30 15:00:32.644                  M.Nikhita
# 7  2020-01-30 15:00:36.728           DASARI PAVAN SAI
# 8  2020-01-30 15:00:39.347              B Jagan Mohan
# 9  2020-01-30 15:00:40.676          k.parameswara rao
# 10 2020-01-30 15:00:42.915           B.Ravindra kumar
# 11 2020-01-30 15:00:44.077        P.M.S.Bhargav Kumar
# 12 2020-01-30 15:00:44.555      Thatavarti kavya sree
# 13 2020-01-30 15:01:10.442               Harish Bandi
# 14 2020-01-30 15:01:15.898     M.Bhavani Sankar Reddy
# 15 2020-01-30 15:01:24.277             Devendra Kumar
# ...

# %% [markdown]
# # Slicing

# %% [markdown]
# ## position bassed indexing
# ## label based indexing

# %%
data.iloc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.iloc[0:1]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.iloc[0:6:2,1:3]
# Out:
#                Name                            MailId
# 0     Sai Naga Raju  sainagarajusakhamuri99@gmail.com
# 2     P K CHAITANYA              chaitu1495@gmail.com
# 4  Himaja cherukuri         himajacherukuri@gmail.com

# %%
data.iloc[-2:,-2:]
# Out:
#    Qualification    RollNumber
# 24        B.TECH    161FA07025
# 25           B.E  245112769310

# %%
data.loc[0]
# Out:
# Timestamp                     30/01/2020 15:00:07
# Name                                Sai Naga Raju
# MailId           sainagarajusakhamuri99@gmail.com
# Branch                                         IT
# Qualification                              B.Tech
# RollNumber                             161FA07039
# Name: 0, dtype: object

# %%
data.loc[0:0]
# Out:
#              Timestamp           Name                            MailId  \
# 0  30/01/2020 15:00:07  Sai Naga Raju  sainagarajusakhamuri99@gmail.com
#
#   Branch Qualification  RollNumber
# 0     IT        B.Tech  161FA07039

# %%
data.loc[24:25,'Qualification':'RollNumber']
# Out:
#    Qualification    RollNumber
# 24        B.TECH    161FA07025
# 25           B.E  245112769310

# %%
data.loc[7:15:4,'Branch':'RollNumber']
# Out:
#                     Branch Qualification    RollNumber
# 7   Information Technology        B.Tech    161FA07042
# 11        Computer Science           MCA  121722501026
# 15                     ECE        B.Tech    14F41A0461
